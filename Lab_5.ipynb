# %% [markdown]
# <a href="https://colab.research.google.com/github/kirti-maker/APS/blob/main/Lab_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2. Divide and Conquer (Sorting)

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# Write a python program to perform **selection sort**.
# - ** -Algorithm
# * Step 1: Read the number of elements for the list from the user.
# * Step 2: Using for loop insert the elements in the list.
# * Step 3: Initialize the minimum element as min=numbers[i].
# * Step 4: Using the swap method the elements are sorted accordingly.
# * Step 5: Print the sorted list.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import random
import matplotlib.pyplot as plt
import numpy as np

def selection_sort(numbers):
    """
    Selection Sort: Find min in unsorted, swap to front.
    Time: O(n²) comparisons/swaps. Space: O(1) in-place.
    """
    n = len(numbers)
    for i in range(n):
        min_idx = i
        for j in range(i + 1, n):
            if numbers[j] < numbers[min_idx]:
                min_idx = j
        numbers[i], numbers[min_idx] = numbers[min_idx], numbers[i]
    return numbers

# --- Interactive input ---
n = int(input("Enter number of elements: "))
numbers = list(map(int, input("Enter elements (space-separated): ").split()))

print("Original:", numbers)
start = time.time()
sorted_numbers = selection_sort(numbers.copy())
end = time.time()
print("Sorted:", sorted_numbers)
print(f"Time taken: {(end - start)*1000:.4f} ms")

# --- Runtime analysis & plot ---
print("\n--- Running Time Analysis ---")
sizes = np.arange(50, 501, 50)
times = []
for size in sizes:
    arr = [random.randint(0, 1000) for _ in range(size)]
    start = time.time()
    selection_sort(arr.copy())
    end = time.time()
    times.append((end - start) * 1000)  # ms

plt.figure(figsize=(10, 6))
plt.plot(sizes, times, 'bo-', label='Measured')
plt.plot(sizes, (sizes**2)/1e6, 'r--', label='O(n²) fit')  # Scaled theoretical
plt.xlabel('Array size n')
plt.ylabel('Time (ms)')
plt.title('Selection Sort: Quadratic O(n²) Runtime')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

print("Analysis complete. Graph shows quadratic growth confirming O(n²).")
# Out:
# Enter number of elements: 5
# Enter elements (space-separated): 1 2 3 4 5
# Original: [1, 2, 3, 4, 5]
# Sorted: [1, 2, 3, 4, 5]
# Time taken: 0.0901 ms
#
# --- Running Time Analysis ---
# Analysis complete. Graph shows quadratic growth confirming O(n²).

# %% [markdown]
# In computer science, **merge sort** (also commonly spelled mergesort) is an efficient, general-purpose, comparison-based sorting algorithm. Most implementations produce a stable sort, which means that the order of equal elements is the same in the input and output. Merge sort is a divide and conquer algorithm that was invented by John von Neumann in 1945.
# Write a Python program to sort the elements using **merge sort** and plot a graph to the time taken versus n
# - Algorithm(Merge Sort is a divide and conquer algorithm. It divides	input array in two halve.s, calls itself for the two halves and then merges two sorted halves.)
# 1.	Divide the unsorted array into n partitions, each	partition contains 1 element.
# 2.	Repeatedly merge partitioned units to produce	new sublists until there is only l sublist remaining. This will be the sorted	.
# 3.	Compare the first element of the sublist with the first element of the sublist to its right.
# 4.	Merge the two sublists by	paring each element of the sublist and placing the smaller element into the	new sublist.
# 5.	Repeat step 3 and 4 untill	all sublists are merged into a single sorted sublist.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import random
import matplotlib.pyplot as plt
import numpy as np

# --- Merge Sort Implementation ---
def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        left_half = arr[:mid]
        right_half = arr[mid:]

        # Recursive calls
        merge_sort(left_half)
        merge_sort(right_half)

        # Merge step
        i = j = k = 0
        while i < len(left_half) and j < len(right_half):
            if left_half[i] < right_half[j]:
                arr[k] = left_half[i]
                i += 1
            else:
                arr[k] = right_half[j]
                j += 1
            k += 1

        # Copy remaining elements
        while i < len(left_half):
            arr[k] = left_half[i]
            i += 1
            k += 1
        while j < len(right_half):
            arr[k] = right_half[j]
            j += 1
            k += 1
    return arr

# --- Interactive input ---
n = int(input("Enter number of elements: "))
numbers = list(map(int, input("Enter elements (space-separated): ").split()))

print("Original:", numbers)
start = time.time()
sorted_numbers = merge_sort(numbers.copy())
end = time.time()
print("Sorted:", sorted_numbers)
print(f"Time taken: {(end - start)*1000:.4f} ms")

# --- Runtime analysis & plot ---
print("\n--- Running Time Analysis ---")
sizes = np.arange(100, 2001, 200)  # test sizes from 100 to 2000
times = []
for size in sizes:
    arr = [random.randint(0, 10000) for _ in range(size)]
    start = time.time()
    merge_sort(arr.copy())
    end = time.time()
    times.append((end - start) * 1000)  # ms

plt.figure(figsize=(10, 6))
plt.plot(sizes, times, 'bo-', label='Measured')
plt.plot(sizes, (sizes*np.log2(sizes))/5000, 'r--', label='O(n log n) fit')  # scaled theoretical
# Out:
# Enter number of elements: 5
# Enter elements (space-separated): 1 2 3 4 5
# Original: [1, 2, 3, 4, 5]
# Sorted: [1, 2, 3, 4, 5]
# Time taken: 0.0949 ms
#
# --- Running Time Analysis ---

# %% [markdown]
# **Quicksort** (sometimes called partition-exchange sort) is an efficient sorting algorithm. Developed by British computer scientist Tony Hoare in 1959 and published in 1961, it is still a commonly used algorithm for sorting.
#
# Quicksort is a divide-and-conquer algorithm. It works by selecting a 'pivot' element from the array and partitioning the other elements into two sub-arrays, according to whether they are less than or greater than the pivot. The sub-arrays are then sorted recursively. This can be done in-place, requiring small additional amounts of memory to perform the sorting.
# Write a Python program to sort the elements using quick sort and plot a graph to the time taken versus n.
# - Algorithm
# 1.	Select a pivot element from the array.
# 2.	Partition the array into two sub-arrays. The elements in the first sub-array are less than the pivot element, while the elements in the second sub-array are greater than the pivot element.
# 3.	Recursively sort the sub-arrays created in Step 2.
# 4.	Join the sub-arrays and the pivot element together to	the sorted array.

# %%
#write code for above cell and compute the running time and also plot graph.
def partition(arr, low, high):
    pivot = arr[high]  # Last as pivot
    i = low - 1
    for j in range(low, high):
        if arr[j] <= pivot:
            i += 1
            arr[i], arr[j] = arr[j], arr[i]
    arr[i + 1], arr[high] = arr[high], arr[i + 1]
    return i + 1

def quick_sort(arr, low=0, high=None):
    if high is None:
        high = len(arr) - 1
    if low < high:
        pi = partition(arr, low, high)
        quick_sort(arr, low, pi - 1)
        quick_sort(arr, pi + 1, high)
    return arr
import time
import random
import matplotlib.pyplot as plt
import numpy as np

def partition(arr, low, high):
    pivot = arr[high]
    i = low - 1
    for j in range(low, high):
        if arr[j] <= pivot:
            i += 1
            arr[i], arr[j] = arr[j], arr[i]
    arr[i + 1], arr[high] = arr[high], arr[i + 1]
    return i + 1

def quick_sort(arr, low=0, high=None):
    if high is None:
        high = len(arr) - 1
    if low < high:
        pi = partition(arr, low, high)
        quick_sort(arr, low, pi - 1)
        quick_sort(arr, pi + 1, high)
    return arr

# User input
n = int(input("Enter number of elements: "))
try:
    line = input("Enter elements (space-separated): ").strip().split()
    if len(line) == n:
        numbers = [int(x) for x in line]
    else:
        raise ValueError
except:
    numbers = []
    for _ in range(n):
        numbers.append(int(input("Enter element: ")))

print("Original:", numbers)
arr = numbers.copy()
start = time.time()
sorted_numbers = quick_sort(arr)
end = time.time()
print("Sorted:", sorted_numbers)
print(f"Time: {(end-start)*1000:.4f} ms")

# Benchmark on random data (avg case)
sizes = np.arange(100, 2001, 100)
times = []
for size in sizes:
    arr = [random.randint(0, 10000) for _ in range(size)]
    start = time.time()
    quick_sort(arr.copy())
    end = time.time()
    times.append((end - start) * 1000)

plt.figure(figsize=(10,6))
plt.plot(sizes, times, 'ro-', label='Avg (Random)')
plt.plot(sizes, sizes * np.log2(sizes) * 0.015, 'g--', label='O(n log n)')  # Fit
plt.xlabel('Array size n')
plt.ylabel('Time (ms)')
plt.title('Quick Sort: Avg O(n log n) Runtime (Hoare 1961)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

print("Avg: O(n log n), Worst: O(n²). In-place, cache-friendly. Fastest practical sort!")
# Out:
# Enter number of elements: 6
# Enter elements (space-separated): 1 2 3 4 5 6
# Original: [1, 2, 3, 4, 5, 6]
# Sorted: [1, 2, 3, 4, 5, 6]
# Time: 0.1333 ms
# Avg: O(n log n), Worst: O(n²). In-place, cache-friendly. Fastest practical sort!

# %% [markdown]
# ### Experiment: compare sorting algorithms

# %%
# Experiment variables
n_list = [1000, 2000, 5000, 10000, 20000, 50000, 100000, 200000]
n_max = n_list[len(n_list) -1]

# %%
#creating random values of different sorting algorithm and comapare it with each other
import time
import random
import matplotlib.pyplot as plt
import numpy as np

# --- Sorting Algorithms ---
def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_idx = i
        for j in range(i+1, n):
            if arr[j] < arr[min_idx]:
                min_idx = j
        arr[i], arr[min_idx] = arr[min_idx], arr[i]
    return arr

def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr)//2
        L = arr[:mid]
        R = arr[mid:]
        merge_sort(L)
        merge_sort(R)
        i = j = k = 0
        while i < len(L) and j < len(R):
            if L[i] < R[j]:
                arr[k] = L[i]; i += 1
            else:
                arr[k] = R[j]; j += 1
            k += 1
        while i < len(L):
            arr[k] = L[i]; i += 1; k += 1
        while j < len(R):
            arr[k] = R[j]; j += 1; k += 1
    return arr

def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr)//2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quick_sort(left) + middle + quick_sort(right)

# --- Experiment Variables ---
n_list = [1000, 2000, 5000, 10000, 20000, 50000, 100000]
a_time, b_time, c_time, d_time = [], [], [], []

for n in n_list:
    arr = [random.randint(0, 100000) for _ in range(n)]

    # Quicksort
    start = time.time()
    quick_sort(arr.copy())
    a_time.append((time.time() - start)*1000)

    # Mergesort
    start = time.time()
    merge_sort(arr.copy())
    b_time.append((time.time() - start)*1000)

    # Selection sort (only for smaller n)
    if n <= 10000:
        start = time.time()
        selection_sort(arr.copy())
        c_time.append((time.time() - start)*1000)
    else:
        c_time.append(None)  # skip for large n

    # Built-in sort
    start = time.time()
    sorted(arr.copy())
    d_time.append((time.time() - start)*1000)

# --- Plotting ---
plt.figure(figsize=(10, 5))
plt.plot(a_time, linewidth=1, marker="o")
plt.plot(b_time, linewidth=1, marker="o")
plt.plot([t for t in c_time if t is not None], linewidth=1, marker="o")
plt.plot(d_time, linewidth=1, marker="o")
plt.xticks(np.arange(len(n_list)), n_list)
plt.title("Compare Sorting Algorithms", fontsize=14)
plt.ylabel("Time (ms)")
plt.xlabel("n")
plt.legend(("Quicksort", "Mergesort", "Selection sort (≤10k)", "Built-in sort"), loc="best")
plt.show()
